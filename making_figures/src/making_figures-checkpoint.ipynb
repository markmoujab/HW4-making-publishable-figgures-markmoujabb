# %% [markdown]
# # HW4
# ## Dataset

# %% [markdown]
# The dataset being used displays the NFL Fantasy Statistics for players in the first 4 weeks of the 2023 NFL Season, the dataset has different attributes such as
# * Player Name
# * Player Team
# * Player Position
# * Projected Points
# * Total Points
# * Opponent
# * Location

# %% [markdown]
# ## Imported Libraries

# %%
from IPython.display import IFrame
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kde
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import seaborn as sns
import networkx as nx

# %% [markdown]
# ## Figure 1: Plot Showing Top 15 Players of Weeks 1-4
# ### top_players.py
# ![image.png](attachment:image.png)

# %% [markdown]
# The bar graph in the figure above displays the top performers in the first four weeks of the NFL season, the purpose of that plot is to see which players should be your top prospects in case they are available to be picked up in your fantasy league.

# %% [markdown]
# ## Figure 2: Scatterplot Comparing Player performances Home vs Away
# ### home_away.py
# ![image.png](attachment:image.png)
#
# The Scatterplot in the figure above allows you to compare how players perform at home games vs at away games. The points on the graph show player total points as a function of player projected points. There is also an x=y line passing through the middle of the graph, which allows the viewer to actually compare performance. The side with more points above the line would have the better performance since that would mean that the total achieved points is greater than the projected points.

# %% [markdown]
# ## Interactive Plot
# ### app.py
#
# ### Imported Libraries

# %%
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd

# %% [markdown]
# This plot allows you to view how players are performing againt a specific team by picking the team from the drop down list. The datapoints are color coded by player positions, and that would allow you to evaluate whether or not the player should be started that week. The file runs using dash, so it needs to be run by typing in the following in the python debugger tab:

# %% [raw]
# python app.py

# %% [markdown]
# That will prompt you to open the following website, which will allow you to look at the plot and pick your team
